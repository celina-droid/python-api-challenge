# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pprint import pprint
import openweathermapy.core as owm
from citipy import citipy
import requests
import seaborn as sns
from datetime import datetime

# Import API key
from api_keys import api_key

# %% [markdown]
# ## Generate Cities List

# %%
# This n determines how many cities we generate
# We also initialize our lists to track the cities

# I chose 700 because many cities will not have data available
# n=700 seemed safe in order to get above the 500 city threshold
n = 700
cities = []
country_codes = []

for x in range(n):
    lat = np.random.uniform(-90, 90)
    lng = np.random.uniform(-180, 180)
    city = citipy.nearest_city(lat, lng)
    
    # Make sure that the randomly generated city is not already in our series
    # If it is, regenerate the lat and lng until we get one that isn't
    while city.city_name in cities:
        lat = np.random.uniform(-90, 90)
        lng = np.random.uniform(-180, 180)
        city = citipy.nearest_city(lat, lng)
    
    # Add the data to our lists
    cities.append(city.city_name)
    country_codes.append(city.country_code)
    
country_codes = [x.upper() for x in country_codes]

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create base URL and indicate imperial units
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Build partial query URL
query = f"{url}appid={api_key}&units={units}&q="

# %%
# Create an "extracts" object to get the temperature, humidity, cloudiness and wind speed
latitude = []
longitude = []
temperature = []
humidity = []
cloudiness = []
wind_speed = []
dates = []


for x in range(len(cities)):
    response = requests.get(f"{query}{cities[x]},{country_codes[x].upper()}").json()
    
    # Some of the cities we generate don't have data in openweathermap, so set their values to numpy's NaN
    try:
        temperature.append(response['main']['temp_max'])
        latitude.append(response['coord']['lat'])
        longitude.append(response['coord']['lon'])
        humidity.append(response['main']['humidity'])
        wind_speed.append(response['wind']['speed'])
        dates.append(response['dt'])
    except KeyError:
        temperature.append(np.nan)
        latitude.append(np.nan)
        longitude.append(np.nan)
        humidity.append(np.nan)
        wind_speed.append(np.nan)
        dates.append(np.nan)
       # cities[x].append(np.nan)
    
    # Sometimes it's not cloudy! Then 'clouds' does not exist, so set it to zero.
    try:
        cloudiness.append(response['clouds']['all'])
    except KeyError:
        cloudiness.append(0)
        
    # Print each city name and query string    
    print(f"Processing record {x + 1} | {cities[x]}")
    print(f"{query}{cities[x]}")

print("--------------------------------------------")
print("Data Processing Complete")
print("--------------------------------------------")

# Assemble everything into a data frame
weather_df = pd.DataFrame({"City": cities,
                           "Latitude": latitude,
                           "Longitude": longitude,
                           "Humidity": humidity,
                           "Max Temp": temperature,
                           "Cloudiness": cloudiness,
                           "Wind Speed": wind_speed,
                           "Date": dates,
                           "Country": country_codes
                          })
# Out:
# Processing record 1 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=albany
# Processing record 2 | kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=kapaa
# Processing record 3 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=ushuaia
# Processing record 4 | conde
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=conde
# Processing record 5 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=busselton
# Processing record 6 | la mana
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=la mana
# Processing record 7 | hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=hermanus
# Processing record 8 | dudinka
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=dudinka
# Processing record 9 | dianopolis
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=dianopolis
# Processing record 10 | bluff
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=bluff
# Processing record 11 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=nanortalik
# Processing record 12 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=deputatskiy
# Processing record 13 | port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=port alfred
# Processing record 14 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=punta arenas
# Processing record 15 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=saint-philippe
# Processing record 16 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=taolanaro
# Processing record 17 | alexandria
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=alexandria
# Processing record 18 | atar
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=atar
# Processing record 19 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=qaanaaq
# Processing record 20 | hilo
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=hilo
# Processing record 21 | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=petropavlovsk-kamchatskiy
# Processing record 22 | kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=kodiak
# Processing record 23 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=ribeira grande
# Processing record 24 | murgab
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=murgab
# Processing record 25 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=rikitea
# Processing record 26 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=illoqqortoormiut
# Processing record 27 | asyut
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=asyut
# Processing record 28 | walvis bay
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=walvis bay
# Processing record 29 | honiara
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=honiara
# Processing record 30 | faanui
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=faanui
# Processing record 31 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=tsihombe
# Processing record 32 | tubuala
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=tubuala
# Processing record 33 | mataura
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=mataura
# Processing record 34 | vila velha
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=vila velha
# Processing record 35 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=new norfolk
# Processing record 36 | cabedelo
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=cabedelo
# Processing record 37 | dukat
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=dukat
# Processing record 38 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=komsomolskiy
# Processing record 39 | hadejia
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=hadejia
# Processing record 40 | sangar
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=sangar
# Processing record 41 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=bengkulu
# Processing record 42 | geraldton
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=geraldton
# Processing record 43 | vung tau
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=vung tau
# Processing record 44 | east london
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=east london
# Processing record 45 | payson
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=payson
# Processing record 46 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=tasiilaq
# Processing record 47 | estelle
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=estelle
# Processing record 48 | aleksandrovsk-sakhalinskiy
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=aleksandrovsk-sakhalinskiy
# Processing record 49 | barrow
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=barrow
# Processing record 50 | andenes
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=andenes
# Processing record 51 | amurzet
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=amurzet
# Processing record 52 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=cape town
# Processing record 53 | puerto del rosario
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=puerto del rosario
# Processing record 54 | lompoc
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=lompoc
# Processing record 55 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=port elizabeth
# Processing record 56 | esperance
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=esperance
# Processing record 57 | tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=tiksi
# Processing record 58 | chumikan
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=chumikan
# Processing record 59 | conceicao da barra
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=conceicao da barra
# Processing record 60 | rio gallegos
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=rio gallegos
# Processing record 61 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=kaitangata
# Processing record 62 | mookane
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=mookane
# Processing record 63 | lapy
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=lapy
# Processing record 64 | nyurba
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=nyurba
# Processing record 65 | sabinas hidalgo
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=sabinas hidalgo
# Processing record 66 | shimoda
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=shimoda
# Processing record 67 | mitzic
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=mitzic
# Processing record 68 | marcona
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=marcona
# Processing record 69 | kavieng
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=kavieng
# Processing record 70 | varhaug
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=varhaug
# Processing record 71 | mezen
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=mezen
# Processing record 72 | jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=jamestown
# Processing record 73 | yenagoa
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=yenagoa
# Processing record 74 | kyle of lochalsh
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=kyle of lochalsh
# Processing record 75 | la paz
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=la paz
# Processing record 76 | atuona
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=atuona
# Processing record 77 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=bredasdorp
# Processing record 78 | labuhan
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=labuhan
# Processing record 79 | ust-nera
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=ust-nera
# Processing record 80 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=tuktoyaktuk
# Processing record 81 | cananeia
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=cananeia
# Processing record 82 | tomatlan
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=tomatlan
# Processing record 83 | tiznit
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=tiznit
# Processing record 84 | piranshahr
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=piranshahr
# Processing record 85 | lebu
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=lebu
# Processing record 86 | jabiru
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=jabiru
# Processing record 87 | chuy
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=chuy
# Processing record 88 | maniitsoq
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=maniitsoq
# Processing record 89 | batagay-alyta
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=batagay-alyta
# Processing record 90 | ancud
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=ancud
# Processing record 91 | furth im wald
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=furth im wald
# Processing record 92 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=cap malheureux
# Processing record 93 | vaini
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=vaini
# Processing record 94 | abha
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=abha
# Processing record 95 | henties bay
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=henties bay
# Processing record 96 | talaya
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=talaya
# Processing record 97 | mazamari
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=mazamari
# Processing record 98 | matara
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=matara
# Processing record 99 | nantucket
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=nantucket
# Processing record 100 | dikson
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=dikson
# Processing record 101 | sarab
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=sarab
# Processing record 102 | hambantota
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=hambantota
# Processing record 103 | narsaq
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=narsaq
# Processing record 104 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=nizhneyansk
# Processing record 105 | khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=khatanga
# Processing record 106 | grand island
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=grand island
# Processing record 107 | shujaabad
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=shujaabad
# Processing record 108 | guadalajara
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=guadalajara
# Processing record 109 | pevek
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=pevek
# Processing record 110 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=mys shmidta
# Processing record 111 | sitka
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=sitka
# Processing record 112 | buraydah
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=buraydah
# Processing record 113 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=puerto ayora
# Processing record 114 | lagoa
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=lagoa
# Processing record 115 | sabang
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=sabang
# Processing record 116 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=attawapiskat
# Processing record 117 | cururupu
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=cururupu
# Processing record 118 | anajatuba
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=anajatuba
# Processing record 119 | gravdal
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=gravdal
# Processing record 120 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=longyearbyen
# Processing record 121 | airai
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=airai
# Processing record 122 | amderma
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=amderma
# Processing record 123 | butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=butaritari
# Processing record 124 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=mar del plata
# Processing record 125 | povenets
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=povenets
# Processing record 126 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=hithadhoo
# Processing record 127 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=carnarvon
# Processing record 128 | neiafu
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=neiafu
# Processing record 129 | oksbol
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=oksbol
# Processing record 130 | severnyy-kospashskiy
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=severnyy-kospashskiy
# Processing record 131 | nioro
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=nioro
# Processing record 132 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=kruisfontein
# Processing record 133 | karlstad
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=karlstad
# Processing record 134 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=barentsburg
# Processing record 135 | coihaique
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=coihaique
# Processing record 136 | gamba
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=gamba
# Processing record 137 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=hobart
# Processing record 138 | mountain home
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=mountain home
# Processing record 139 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=beringovskiy
# Processing record 140 | kerrobert
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=kerrobert
# Processing record 141 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=bathsheba
# Processing record 142 | iranshahr
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=iranshahr
# Processing record 143 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=meulaboh
# Processing record 144 | samusu
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=samusu
# Processing record 145 | mitu
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=mitu
# Processing record 146 | port keats
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=port keats
# Processing record 147 | kuytun
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=kuytun
# Processing record 148 | richards bay
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=richards bay
# Processing record 149 | jurm
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=jurm
# Processing record 150 | nguiu
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=nguiu
# Processing record 151 | termoli
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=termoli
# Processing record 152 | winnemucca
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=winnemucca
# Processing record 153 | abu samrah
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=abu samrah
# Processing record 154 | lamesa
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=lamesa
# Processing record 155 | mount isa
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=mount isa
# Processing record 156 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=port lincoln
# Processing record 157 | shingu
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=shingu
# Processing record 158 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=klaksvik
# Processing record 159 | te anau
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=te anau
# Processing record 160 | hasaki
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=hasaki
# Processing record 161 | bethel
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=bethel
# Processing record 162 | port hardy
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=port hardy
# Processing record 163 | ngukurr
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=ngukurr
# Processing record 164 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=tuatapere
# Processing record 165 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=ponta delgada
# Processing record 166 | dwarka
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=dwarka
# Processing record 167 | hami
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=hami
# Processing record 168 | grindavik
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=grindavik
# Processing record 169 | alamos
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=alamos
# Processing record 170 | suez
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=suez
# Processing record 171 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=vaitupu
# Processing record 172 | port-cartier
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=port-cartier
# Processing record 173 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=arraial do cabo
# Processing record 174 | espanola
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=espanola
# Processing record 175 | amapa
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=amapa
# Processing record 176 | torquay
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=torquay
# Processing record 177 | tezu
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=tezu
# Processing record 178 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=tumannyy
# Processing record 179 | ulladulla
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=ulladulla
# Processing record 180 | taltal
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=taltal
# Processing record 181 | lasa
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=lasa
# Processing record 182 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=nikolskoye
# Processing record 183 | alofi
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=alofi
# Processing record 184 | maues
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=maues
# Processing record 185 | victoria
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=victoria
# Processing record 186 | torbay
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=torbay
# Processing record 187 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=fairbanks
# Processing record 188 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=tilichiki
# Processing record 189 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=yellowknife
# Processing record 190 | khasan
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=khasan
# Processing record 191 | avarua
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=avarua
# Processing record 192 | mayo
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=mayo
# Processing record 193 | cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=cidreira
# Processing record 194 | concordia
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=concordia
# Processing record 195 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=cabo san lucas
# Processing record 196 | susanville
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=susanville
# Processing record 197 | waipawa
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=waipawa
# Processing record 198 | samarai
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=samarai
# Processing record 199 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=mahebourg
# Processing record 200 | tura
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=tura
# Processing record 201 | souillac
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=souillac
# Processing record 202 | ahipara
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=ahipara
# Processing record 203 | hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=hamilton
# Processing record 204 | katsuura
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=katsuura
# Processing record 205 | norman wells
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=norman wells
# Processing record 206 | leh
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=leh
# Processing record 207 | inderborskiy
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=inderborskiy
# Processing record 208 | bol
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=bol
# Processing record 209 | nizwa
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=nizwa
# Processing record 210 | vardo
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=vardo
# Processing record 211 | satitoa
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=satitoa
# Processing record 212 | clyde river
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=clyde river
# Processing record 213 | san patricio
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=san patricio
# Processing record 214 | muyezerskiy
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=muyezerskiy
# Processing record 215 | vanimo
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=vanimo
# Processing record 216 | jingdezhen
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=jingdezhen
# Processing record 217 | swidnica
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=swidnica
# Processing record 218 | dagami
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=dagami
# Processing record 219 | dingle
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=dingle
# Processing record 220 | ende
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=ende
# Processing record 221 | seguela
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=seguela
# Processing record 222 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=bambous virieux
# Processing record 223 | peace river
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=peace river
# Processing record 224 | guiratinga
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=guiratinga
# Processing record 225 | nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=nhulunbuy
# Processing record 226 | carbonia
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=carbonia
# Processing record 227 | new milford
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=new milford
# Processing record 228 | koscierzyna
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=koscierzyna
# Processing record 229 | thompson
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=thompson
# Processing record 230 | emba
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=emba
# Processing record 231 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=grand river south east
# Processing record 232 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=yerbogachen
# Processing record 233 | babaeski
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=babaeski
# Processing record 234 | makakilo city
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=makakilo city
# Processing record 235 | moose factory
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=moose factory
# Processing record 236 | bundaberg
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=bundaberg
# Processing record 237 | vao
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=vao
# Processing record 238 | poso
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=poso
# Processing record 239 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=iqaluit
# Processing record 240 | ishigaki
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=ishigaki
# Processing record 241 | pimentel
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=pimentel
# Processing record 242 | west bay
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=west bay
# Processing record 243 | tautira
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=tautira
# Processing record 244 | lanxi
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=lanxi
# Processing record 245 | koumac
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=koumac
# Processing record 246 | kolosovka
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=kolosovka
# Processing record 247 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=lavrentiya
# Processing record 248 | san felipe
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=san felipe
# Processing record 249 | orsha
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=orsha
# Processing record 250 | umm lajj
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=umm lajj
# Processing record 251 | jinka
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=jinka
# Processing record 252 | baishishan
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=baishishan
# Processing record 253 | flinders
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=flinders
# Processing record 254 | nortelandia
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=nortelandia
# Processing record 255 | evensk
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=evensk
# Processing record 256 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=cherskiy
# Processing record 257 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=oranjemund
# Processing record 258 | batocina
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=batocina
# Processing record 259 | kyren
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=kyren
# Processing record 260 | linxia
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=linxia
# Processing record 261 | louisbourg
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=louisbourg
# Processing record 262 | kytlym
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=kytlym
# Processing record 263 | tevaitoa
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=tevaitoa
# Processing record 264 | camacha
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=camacha
# Processing record 265 | caravelas
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=caravelas
# Processing record 266 | najran
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=najran
# Processing record 267 | kahului
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=kahului
# Processing record 268 | dunedin
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=dunedin
# Processing record 269 | puro
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=puro
# Processing record 270 | russellville
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=russellville
# Processing record 271 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=kavaratti
# Processing record 272 | castro
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=castro
# Processing record 273 | kolyvan
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=kolyvan
# Processing record 274 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=ostrovnoy
# Processing record 275 | labutta
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=labutta
# Processing record 276 | georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=georgetown
# Processing record 277 | salalah
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=salalah
# Processing record 278 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=praia da vitoria
# Processing record 279 | kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=kudahuvadhoo
# Processing record 280 | broken hill
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=broken hill
# Processing record 281 | dekernes
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=dekernes
# Processing record 282 | la ronge
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=la ronge
# Processing record 283 | bargal
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=bargal
# Processing record 284 | gubkinskiy
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=gubkinskiy
# Processing record 285 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=chokurdakh
# Processing record 286 | lucapa
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=lucapa
# Processing record 287 | tommot
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=tommot
# Processing record 288 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=saskylakh
# Processing record 289 | provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=provideniya
# Processing record 290 | ulagan
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=ulagan
# Processing record 291 | san lorenzo
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=san lorenzo
# Processing record 292 | robertsport
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=robertsport
# Processing record 293 | cadiz
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=cadiz
# Processing record 294 | bathurst
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=bathurst
# Processing record 295 | aketi
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=aketi
# Processing record 296 | novocheboksarsk
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=novocheboksarsk
# Processing record 297 | eyl
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=eyl
# Processing record 298 | paamiut
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=paamiut
# Processing record 299 | romanovo
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=romanovo
# Processing record 300 | jumla
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=jumla
# Processing record 301 | naze
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=naze
# Processing record 302 | pandan
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=pandan
# Processing record 303 | gumdag
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=gumdag
# Processing record 304 | lamar
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=lamar
# Processing record 305 | mokrousovo
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=mokrousovo
# Processing record 306 | husavik
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=husavik
# Processing record 307 | palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=palabuhanratu
# Processing record 308 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=udachnyy
# Processing record 309 | manama
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=manama
# Processing record 310 | sinjar
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=sinjar
# Processing record 311 | antsohihy
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=antsohihy
# Processing record 312 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=saint-francois
# Processing record 313 | doha
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=doha
# Processing record 314 | semnan
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=semnan
# Processing record 315 | upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=upernavik
# Processing record 316 | tukrah
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=tukrah
# Processing record 317 | camopi
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=camopi
# Processing record 318 | baruun-urt
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=baruun-urt
# Processing record 319 | pontes e lacerda
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=pontes e lacerda
# Processing record 320 | lac du bonnet
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=lac du bonnet
# Processing record 321 | sur
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=sur
# Processing record 322 | constitucion
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=constitucion
# Processing record 323 | klyuchi
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=klyuchi
# Processing record 324 | pullman
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=pullman
# Processing record 325 | bay roberts
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=bay roberts
# Processing record 326 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=umzimvubu
# Processing record 327 | ekhabi
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=ekhabi
# Processing record 328 | taquarituba
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=taquarituba
# Processing record 329 | krasnaya gora
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=krasnaya gora
# Processing record 330 | knin
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=knin
# Processing record 331 | praya
# ...
# Processing record 593 | roald
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=roald
# Processing record 594 | hearst
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=hearst
# Processing record 595 | bandiagara
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=bandiagara
# Processing record 596 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=coquimbo
# Processing record 597 | kuche
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=kuche
# Processing record 598 | sao felix do xingu
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=sao felix do xingu
# Processing record 599 | killybegs
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=killybegs
# Processing record 600 | haibowan
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=haibowan
# Processing record 601 | westport
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=westport
# Processing record 602 | florian
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=florian
# Processing record 603 | auki
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=auki
# Processing record 604 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=ilulissat
# Processing record 605 | fort saint john
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=fort saint john
# Processing record 606 | sambava
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=sambava
# Processing record 607 | rovaniemi
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=rovaniemi
# Processing record 608 | taburi
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=taburi
# Processing record 609 | karaul
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=karaul
# Processing record 610 | padre bernardo
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=padre bernardo
# Processing record 611 | san jose
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=san jose
# Processing record 612 | konstantinovka
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=konstantinovka
# Processing record 613 | gumrak
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=gumrak
# Processing record 614 | contamana
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=contamana
# Processing record 615 | vestmanna
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=vestmanna
# Processing record 616 | timizart
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=timizart
# Processing record 617 | gol
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=gol
# Processing record 618 | dawlatabad
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=dawlatabad
# Processing record 619 | galle
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=galle
# Processing record 620 | bilibino
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=bilibino
# Processing record 621 | cayenne
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=cayenne
# Processing record 622 | port moresby
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=port moresby
# Processing record 623 | farmington
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=farmington
# Processing record 624 | lake havasu city
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=lake havasu city
# Processing record 625 | yirol
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=yirol
# Processing record 626 | trincomalee
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=trincomalee
# Processing record 627 | langsa
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=langsa
# Processing record 628 | bend
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=bend
# Processing record 629 | sao gabriel da cachoeira
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=sao gabriel da cachoeira
# Processing record 630 | krasnyy kholm
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=krasnyy kholm
# Processing record 631 | avera
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=avera
# Processing record 632 | gazanjyk
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=gazanjyk
# Processing record 633 | hay river
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=hay river
# Processing record 634 | belyy yar
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=belyy yar
# Processing record 635 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=saint anthony
# Processing record 636 | mwene-ditu
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=mwene-ditu
# Processing record 637 | ziniare
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=ziniare
# Processing record 638 | havre
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=havre
# Processing record 639 | banon
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=banon
# Processing record 640 | kloulklubed
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=kloulklubed
# Processing record 641 | pointe michel
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=pointe michel
# Processing record 642 | amguri
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=amguri
# Processing record 643 | fallon
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=fallon
# Processing record 644 | zilair
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=zilair
# Processing record 645 | mana
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=mana
# Processing record 646 | oriximina
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=oriximina
# Processing record 647 | felidhoo
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=felidhoo
# Processing record 648 | lithakia
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=lithakia
# Processing record 649 | barahona
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=barahona
# Processing record 650 | wahran
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=wahran
# Processing record 651 | karratha
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=karratha
# Processing record 652 | talnakh
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=talnakh
# Processing record 653 | margate
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=margate
# Processing record 654 | tongren
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=tongren
# Processing record 655 | ampanihy
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=ampanihy
# Processing record 656 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=sisimiut
# Processing record 657 | bauchi
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=bauchi
# Processing record 658 | kagadi
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=kagadi
# Processing record 659 | tabiauea
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=tabiauea
# Processing record 660 | cruzeiro
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=cruzeiro
# Processing record 661 | praia
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=praia
# Processing record 662 | kihei
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=kihei
# Processing record 663 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=ketchikan
# Processing record 664 | pontian kecil
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=pontian kecil
# Processing record 665 | bari
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=bari
# Processing record 666 | alice springs
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=alice springs
# Processing record 667 | bam
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=bam
# Processing record 668 | general roca
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=general roca
# Processing record 669 | meridian
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=meridian
# Processing record 670 | nador
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=nador
# Processing record 671 | raudeberg
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=raudeberg
# Processing record 672 | ambodifototra
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=ambodifototra
# Processing record 673 | grand forks
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=grand forks
# Processing record 674 | hofn
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=hofn
# Processing record 675 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=mount gambier
# Processing record 676 | phultala
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=phultala
# Processing record 677 | verkhoyansk
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=verkhoyansk
# Processing record 678 | madera
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=madera
# Processing record 679 | newcastleton
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=newcastleton
# Processing record 680 | svarstad
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=svarstad
# Processing record 681 | shahreza
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=shahreza
# Processing record 682 | korhogo
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=korhogo
# Processing record 683 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=cockburn town
# Processing record 684 | santarem
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=santarem
# Processing record 685 | krasnoselkup
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=krasnoselkup
# Processing record 686 | dagana
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=dagana
# Processing record 687 | manolas
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=manolas
# Processing record 688 | bocana de paiwas
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=bocana de paiwas
# Processing record 689 | nha trang
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=nha trang
# Processing record 690 | katobu
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=katobu
# Processing record 691 | les cayes
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=les cayes
# Processing record 692 | khartoum
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=khartoum
# Processing record 693 | formoso do araguaia
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=formoso do araguaia
# Processing record 694 | sindor
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=sindor
# Processing record 695 | micheweni
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=micheweni
# Processing record 696 | kimbe
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=kimbe
# Processing record 697 | along
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=along
# Processing record 698 | pendleton
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=pendleton
# Processing record 699 | cortazar
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=cortazar
# Processing record 700 | little rock
# http://api.openweathermap.org/data/2.5/weather?appid=f18d6285568a0a17d71cad5d1d5e2efb&units=imperial&q=little rock
# --------------------------------------------
# Data Processing Complete
# --------------------------------------------

# %%
# Remove any cities that have NaN values
weather_df = weather_df.dropna(how='any')

print(f"The data frame contains {len(weather_df['City'])} unique cities.")
# Out:
# The data frame contains 614 unique cities.

# %%
weather_df.head()
# Out:
#         City  Latitude  Longitude  Humidity  Max Temp  Cloudiness  Wind Speed  \
# 0     albany    -35.02     117.88      89.0     57.70         100        5.14
# 1      kapaa     22.08    -159.32      92.0     68.41           3        3.38
# 2    ushuaia    -54.81     -68.31      98.0     37.00         100        0.89
# 3      conde    -11.81     -37.61      72.0     78.24          99       11.03
# 4  busselton    -33.64     115.35      78.0     62.73         100       11.86
#
#            Date Country
# 0  1.572092e+09      AU
# 1  1.572092e+09      US
# 2  1.572092e+09      AR
# 3  1.572092e+09      BR
# 4  1.572092e+09      AU

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Set the aesthetic using Seaborn
sns.set()

# Increase the size of the figure
plt.figure(figsize=(9,6))

# Plot the lat vs the max temp
plt.scatter(x = weather_df['Latitude'], y = weather_df['Max Temp'],
            linewidths = 0.75, edgecolors = 'black', color = 'blue', s=35)

# Add labeling
# This extracts the date and returns it in the local time zone
weather_dt = datetime.fromtimestamp(weather_df.loc[0,"Date"]).strftime('%Y-%m-%d')
plt.title(f"Latitude vs. Max Temperature ({weather_dt})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# Modify ticks
plt.xlim(-80,100)
plt.ylim(min(weather_df['Max Temp']) - 10, max(weather_df['Max Temp']) + 10)


plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Set the aesthetic using Seaborn
sns.set()

# Increase the size of the figure
plt.figure(figsize=(9,6))

# Plot the lat vs the max temp
plt.scatter(x = weather_df['Latitude'], y = weather_df['Humidity'],
            linewidths = 0.75, edgecolors = 'black', color = 'blue', s=35)

# Add labeling
# This extracts the date and returns it in the local time zone
weather_dt = datetime.fromtimestamp(weather_df.loc[0,"Date"]).strftime('%Y-%m-%d')
plt.title(f"Latitude vs. Humidity ({weather_dt})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Modify ticks
plt.xlim(-80,100)
plt.ylim(-10, 110)


plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Set the aesthetic using Seaborn
sns.set()

# Increase the size of the figure
plt.figure(figsize=(9,6))

# Plot the lat vs the max temp
plt.scatter(x = weather_df['Latitude'], y = weather_df['Cloudiness'],
            linewidths = 0.75, edgecolors = 'black', color = 'blue', s=35)

# Add labeling
# This extracts the date and returns it in the local time zone
weather_dt = datetime.fromtimestamp(weather_df.loc[0,"Date"]).strftime('%Y-%m-%d')
plt.title(f"Latitude vs. Cloudiness ({weather_dt})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Modify ticks
plt.xlim(-80,100)
plt.ylim(-10, 110)


plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Set the aesthetic using Seaborn
sns.set()

# Increase the size of the figure
plt.figure(figsize=(9,6))

# Plot the lat vs the max temp
plt.scatter(x = weather_df['Latitude'], y = weather_df['Wind Speed'],
            linewidths = 0.75, edgecolors = 'black', color = 'blue', s=35)

# Add labeling
# This extracts the date and returns it in the local time zone
weather_dt = datetime.fromtimestamp(weather_df.loc[0,"Date"]).strftime('%Y-%m-%d')
plt.title(f"Latitude vs. Wind Speed ({weather_dt})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Modify ticks
plt.xlim(-80,100)
plt.ylim(-5, max(weather_df['Wind Speed'])+5)


plt.show()
